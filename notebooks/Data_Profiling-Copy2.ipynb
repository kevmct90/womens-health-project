# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import pandas_profiling
import numpy as np

path = '/Users/Kevin/Desktop/DataKind/womens-health-project/data/raw/DWWC Bookings.csv'

# %% [markdown]
# ## Load in dataset

# %%
# %%bash
# file -I "/Users/Kevin/Desktop/DataKind/womens-health-project/data/raw/DWWC Bookings.csv"
# Out:
# /Users/Kevin/Desktop/DataKind/womens-health-project/data/raw/DWWC Bookings.csv: text/plain; charset=us-ascii

# %%
df=pd.read_csv(path, encoding='ascii')

# %%
df.head()
# Out:
#      ID Date Submitted Date of Birth Preferred means of contact:  \
# 0  4420       03/02/17      04/01/95                       phone
# 1  4419       03/02/17      26/03/92                      e-mail
# 2  4418       03/02/17      09/01/87                      e-mail
# 3  4417       03/02/17           NaN                       phone
# 4  4416       03/02/17      01/12/94                phone,e-mail
#
#   Have you attended one of our clinics before Choose a clinic  \
# 0                                          No         Coolock
# 1                                          No   Liffey Street
# 2                                          No   Liffey Street
# 3                                         Yes   Pembroke Road
# 4                                          No   Liffey Street
#
#                                     Service required  \
# 0                      Mirena / Jaydess Consultation
# 1  General Counselling (eg relationship, stress, ...
# ...

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
# ...

# %% [markdown]
# ## Save report to file

# %%
pfr = pandas_profiling.ProfileReport(df)
pfr.to_file("/Users/Kevin/Desktop/DataKind/womens-health-project/data/raw/Data_Profiling.html")

# %% [markdown]
# Print existing ProfileReport object inline

# %%
pfr
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
# ...

# %%
# Example: Constant variable
df['Clean-Date of Birth'] = pd.to_datetime(df['Date of Birth'], errors='coerce')
df['Clean-Date of Length'] = df['Clean-Date of Birth'].astype(str).str.len()
df.head()
# Out:
#      ID Date Submitted Date of Birth Preferred means of contact:  \
# 0  4420       03/02/17      04/01/95                       phone
# 1  4419       03/02/17      26/03/92                      e-mail
# 2  4418       03/02/17      09/01/87                      e-mail
# 3  4417       03/02/17           NaN                       phone
# 4  4416       03/02/17      01/12/94                phone,e-mail
#
#   Have you attended one of our clinics before Choose a clinic  \
# 0                                          No         Coolock
# 1                                          No   Liffey Street
# 2                                          No   Liffey Street
# 3                                         Yes   Pembroke Road
# 4                                          No   Liffey Street
#
#                                     Service required  \
# 0                      Mirena / Jaydess Consultation
# 1  General Counselling (eg relationship, stress, ...
# ...

# %%
pfr2 = pandas_profiling.ProfileReport(df)
pfr2.to_file("/Users/Kevin/Desktop/DataKind/womens-health-project/data/raw/Data_Profiling2.html")

# %%
pfr2
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
# ...
